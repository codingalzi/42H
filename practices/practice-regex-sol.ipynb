# %% [markdown]
# # (연습) 정규표현식

# %% [markdown]
# **주의 사항**
#
# * 기존에 작성된 코드 셀과 텍스트 셀은 수정하지 않는다.
# * 필요한 경우 코드 셀 또는 텍스트 셀을 추가해서 사용한다.

# %%
import re

# %% [markdown]
# **문제 1**

# %% [markdown]
# | 매칭 | 문자열 |
# | :---: | :--- |
# | 성사 | `3.14529` |
# | 성사 | `-255.34` |
# | 성사 | `128` |
# | 성사 | `1.9e10` |
# | 성사 | `123,340.00` |
# | 미성사 | `720p` |

# %% [markdown]
# 답:

# %%
regex = r'^-?\d+(,\d+)*(\.\d+(e\d+)?)?$'

# %%
re.search(regex, '3.14529')
# Out:
# <re.Match object; span=(0, 7), match='3.14529'>

# %%
re.search(regex, '-255.34')
# Out:
# <re.Match object; span=(0, 7), match='-255.34'>

# %%
re.search(regex, '128')
# Out:
# <re.Match object; span=(0, 3), match='128'>

# %%
re.search(regex, '1.9e10')
# Out:
# <re.Match object; span=(0, 6), match='1.9e10'>

# %%
re.search(regex, '123,340.00')
# Out:
# <re.Match object; span=(0, 10), match='123,340.00'>

# %%
re.search(regex, '720p')

# %% [markdown]
# **문제 2**

# %% [markdown]
# | 그룹 지정 | 문자열 | 그룹 |
# | :---: | :--- | :--- |
# | 성사 | `415-555-1234` | `415` |
# | 성사 | `(416)555-3456` | `416` |
# | 성사 | `202 555 4567` | `202` |
# | 성사 | `4035555678` | `403` |
# | 성사 | `+82 416 555 9292` | `416` |

# %%
regex = r'(?:\+82)?[\s-]?\(?(\d{3})\)?[\s-]?\d{3}[\s-]?\d{4}'

# %%
match = re.search(regex, '415-555-1234')
match
# Out:
# <re.Match object; span=(0, 12), match='415-555-1234'>

# %%
match.group(1)
# Out:
# '415'

# %%
match = re.search(regex, '(416)555-3456')
match
# Out:
# <re.Match object; span=(0, 13), match='(416)555-3456'>

# %%
match.group(1)
# Out:
# '416'

# %%
match = re.search(regex, '202 555 4567')
match
# Out:
# <re.Match object; span=(0, 12), match='202 555 4567'>

# %%
match.group(1)
# Out:
# '202'

# %%
match = re.search(regex, '4035555678')
match
# Out:
# <re.Match object; span=(0, 10), match='4035555678'>

# %%
match.group(1)
# Out:
# '403'

# %%
match = re.search(regex, '+82 416 555 9292')
match
# Out:
# <re.Match object; span=(0, 16), match='+82 416 555 9292'>

# %%
match.group(1)
# Out:
# '416'

# %% [markdown]
# **문제 3**

# %% [markdown]
# | 그룹 지정 | 문자열 | 그룹 |
# | :---: | :--- | :--- |
# | 성사 | `tom@hogwarts.com` | `tom` |
# | 성사 | `tom.riddle@hogwarts.com` | `tom.riddle` |
# | 성사 | `tom.riddle+regexone@hogwarts.com` | `tom.riddle` |
# | 성사 | `tom@hogwarts.eu.com` | `tom` |
# | 성사 | `potter@hogwarts.com` | `potter` |
# | 성사 | `harry@hogwarts.com` | `harry` |
# | 성사 | `hermione+regexone@hogwarts.com` | `hermione` |

# %%
pattern = re.compile(r'^([\w\.]+)')

# %%
match = pattern.search('tom@hogwarts.com')
match
# Out:
# <re.Match object; span=(0, 3), match='tom'>

# %%
match.group(1)
# Out:
# 'tom'

# %%
match = pattern.search('tom.riddle@hogwarts.com')
match
# Out:
# <re.Match object; span=(0, 10), match='tom.riddle'>

# %%
match.group(1)
# Out:
# 'tom.riddle'

# %%
match = pattern.search('tom.riddle+regexone@hogwarts.com')
match
# Out:
# <re.Match object; span=(0, 10), match='tom.riddle'>

# %%
match.group(1)
# Out:
# 'tom.riddle'

# %%
match = pattern.search('tom@hogwarts.eu.com')
match
# Out:
# <re.Match object; span=(0, 3), match='tom'>

# %%
match.group(1)
# Out:
# 'tom'

# %% [markdown]
# **문제 4**

# %% [markdown]
# | 그룹 지정 | 문자열 | 그룹 |
# | :---: | :--- | :--- |
# | 성사 | `<a>This is a link</a>` | `a` |
# | 성사 | `<a href='https://regexone.com'>Link</a>` | `a` |
# | 성사 | `<div class='test_style'>Test</div>` | `div` |
# | 성사 | `<div>Hello <span>world</span></div>` | `div` |

# %%
pattern = re.compile(r'<(\w+)')

# %%
match = pattern.match('<a>This is a link</a>')
match
# Out:
# <re.Match object; span=(0, 2), match='<a'>

# %%
match.group(1)
# Out:
# 'a'

# %%
match = pattern.match("<a href='https://regexone.com'>Link</a>")
match
# Out:
# <re.Match object; span=(0, 2), match='<a'>

# %%
match.group(0)
# Out:
# '<a'

# %%
match.group(1)
# Out:
# 'a'

# %%
match = pattern.match("<div class='test_style'>Test</div>")
match
# Out:
# <re.Match object; span=(0, 4), match='<div'>

# %%
match.group(0)
# Out:
# '<div'

# %%
match.group(1)
# Out:
# 'div'

# %%
match = pattern.match("<div>Hello <span>world</span></div>")
match
# Out:
# <re.Match object; span=(0, 4), match='<div'>

# %%
match.group(0)
# Out:
# '<div'

# %%
match.group(1)
# Out:
# 'div'

# %% [markdown]
# **문제 5**

# %% [markdown]
# | 그룹 지정 | 문자열 | 그룹 |
# | :---: | :--- | :--- |
# | 성사 | `<a>This is a link</a>` | `a` |
# | 성사 | `<a href='https://regexone.com'>Link</a>` | `a` |
# | 성사 | `<div class='test_style'>Test</div>` | `div` |
# | 성사 | `<div>Hello <span>world</span></div>` | `div` |

# %%
match = re.search(r'>([\w\s]*)<', '<a>This is a link</a>')
match
# Out:
# <re.Match object; span=(2, 18), match='>This is a link<'>

# %%
match.group(0)
# Out:
# '>This is a link<'

# %%
match.group(1)
# Out:
# 'This is a link'

# %%
match = re.search(r'>([\w\s]*)<', "<a href='https://regexone.com'>Link</a>")
match
# Out:
# <re.Match object; span=(30, 36), match='>Link<'>

# %%
match.group(0)
# Out:
# '>Link<'

# %%
match.group(1)
# Out:
# 'Link'

# %%
match = re.search(r'>([\w\s]*)<', "<div class='test_style'>Test</div>")
match
# Out:
# <re.Match object; span=(23, 29), match='>Test<'>

# %%
match.group(0)
# Out:
# '>Test<'

# %%
match.group(1)
# Out:
# 'Test'

# %%
match = re.search(r'>([\w\s]*)<', "<div>Hello <span>world</span></div>")
match
# Out:
# <re.Match object; span=(4, 12), match='>Hello <'>

# %%
match.group(0)
# Out:
# '>Hello <'

# %%
match.group(1)
# Out:
# 'Hello '

# %%
match = re.search(r"='([\w:/\.]*)'", "<a href='https://regexone.com'>Link</a>")
match
# Out:
# <re.Match object; span=(7, 30), match="='https://regexone.com'">

# %%
match.group(0)
# Out:
# "='https://regexone.com'"

# %%
match.group(1)
# Out:
# 'https://regexone.com'

# %%
match = re.search(r"='([\w:/\.]*)'", "<div class='test_style'>Test</div>")
match
# Out:
# <re.Match object; span=(10, 23), match="='test_style'">

# %%
match.group(0)
# Out:
# "='test_style'"

# %%
match.group(1)
# Out:
# 'test_style'

# %% [markdown]
# **문제 2**

# %% [markdown]
# | 그룹 지정 | 문자열 | 그룹 |
# | :---: | :--- | :--- |
# | 미성사 | `.bash_profile` | |
# | 미성사 | `workspace.doc` | |
# | 성사 | `imatch0912.jpg` | `imatch0912` `jpg` |
# | 성사 | `updated_imatch0912.png` | `updated_imatch0912` `png` |
# | 미성사 | `documentation.html` | |
# | 성사 | `favicon.gig` | `favicon` `gif` |
# | 미성사 | `imatch0912.jpg.tmp` | |
# | 미성사 | `access.lock` | |

# %%
match = re.search(r'(\w+)\.(jpg|png|gif)$', '.bash_profile')
match

# %%
match = re.search(r'(\w+)\.(jpg|png|gif)$', 'workspace.doc')
match

# %%
match = re.search(r'(\w+)\.(jpg|png|gif)$', 'imatch0912.jpg')
match
# Out:
# <re.Match object; span=(0, 14), match='imatch0912.jpg'>

# %%
match.group(1)
# Out:
# 'imatch0912'

# %%
match.group(2)
# Out:
# 'jpg'

# %%
match = re.search(r'(\w+)\.(jpg|png|gif)$', 'updated_imatch0912.png')
match
# Out:
# <re.Match object; span=(0, 22), match='updated_imatch0912.png'>

# %%
match.group(1)
# Out:
# 'updated_imatch0912'

# %%
match.group(2)
# Out:
# 'png'

# %% [markdown]
# **문제 2**

# %% [markdown]
# | 그룹 지정 | 문자열 | 그룹 |
# | :---: | :--- | :--- |
# | 성사 | `    The quick brown fox...` | `The quick brown fox...` |
# | 성사 | `jumps over the lazy dog.    ` | `jumps over the lazy dog.` |

# %%
match = re.search(r'^\s*(.*)\s*$', '    The quick brown fox...')
match
# Out:
# <re.Match object; span=(0, 26), match='    The quick brown fox...'>

# %%
match.group(1)
# Out:
# 'The quick brown fox...'

# %%
match = re.search(r'^\s*(\w+\s?)*\s*$', '    jumps over the lazy dog.    ')
match

# %%
match.group(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 match.group(1)
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
match = re.search(r'^\s*((?:[\w\.]+\s)*[\w\.]+)\s*$', '    jumps over the lazy dog.    ')
match

# %%
match.group(1)

# %% [markdown]
# **문제 2**

# %% [markdown]
# | 그룹 지정 | 문자열 | 그룹 |
# | :---: | :--- | :--- |
# | 미성사 | `W/dalvikvm( 1553): threadid=1: uncaught exception` | |
# | 미성사 | `E/( 1553): FATAL EXCEPTION: main` | |
# | 미성사 | `E/( 1553): java.lang.StringIndexOutOfBoundsException` | |
# | 성사 | `E/( 1553):   at widget.List.makeView(ListView.java:1727)` | `makeView` `ListView.java` `1727` |
# | 성사 | `	E/( 1553):   at widget.List.fillDown(ListView.java:652)` | `fillDown` `ListView.java` `652` |
# | 성사 | `E/( 1553):   at widget.List.fillFrom(ListView.java:709)` | `fillFrom` `ListView.java` `709` |

# %%
match = re.search(r'(\w+)\(([\w\.]+):(\d+)\)', 'W/dalvikvm( 1553): threadid=1: uncaught exception')
match

# %%
match = re.search(r'(\w+)\(([\w\.]+):(\d+)\)', 'E/( 1553): FATAL EXCEPTION: main')
match

# %%
match = re.search(r'(\w+)\(([\w\.]+):(\d+)\)', 'E/( 1553):   at widget.List.makeView(ListView.java:1727)')
match
# Out:
# <re.Match object; span=(28, 56), match='makeView(ListView.java:1727)'>

# %%
match.group(1)
# Out:
# 'makeView'

# %%
match.group(2)
# Out:
# 'ListView.java'

# %%
match.group(3)
# Out:
# '1727'

# %%
match = re.search(r'(\w+)\(([\w\.]+):(\d+)\)', 'E/( 1553):   at widget.List.fillFrom(ListView.java:709)')
match
# Out:
# <re.Match object; span=(28, 55), match='fillFrom(ListView.java:709)'>

# %%
match.group(1)
# Out:
# 'fillFrom'

# %%
match.group(2)
# Out:
# 'ListView.java'

# %%
match.group(3)
# Out:
# '709'

# %% [markdown]
# **문제 2**

# %% [markdown]
# | 그룹 지정 | 문자열 | 그룹 |
# | :---: | :--- | :--- |
# | 성사 | `ftp://file_server.com:21/top_secret/life_changing_plans.pdf` | `ftp` `file_server.com` `21` |
# | 성사 | `https://regexone.com/lesson/introduction#section` | `https` `regexone.com` |
# | 성사 | `file://localhost:4040/zip_file` | `file` `localhost` `4040` |
# | 성사 | `https://s3cur3-server.com:9999/` | `https` `s3cur3-server.com` `9999` |
# | 성사 | `market://search/angry%20birds` | `market` `search` |

# %%
match = re.search(r'(\w+):\/\/([\w\.\-]+)(:(\d+))*', 'ftp://file_server.com:21/top_secret/life_changing_plans.pdf')
match
# Out:
# <re.Match object; span=(0, 24), match='ftp://file_server.com:21'>

# %%
match.group(1)
# Out:
# 'ftp'

# %%
match.group(2)
# Out:
# 'file_server.com'

# %%
match.group(3)
# Out:
# ':21'

# %%
match.group(4)
# Out:
# '21'

# %%
match = re.search(r'(\w+):\/\/([\w\.\-]+)(:(\d+))*', 'https://regexone.com/lesson/introduction#section')
match
# Out:
# <re.Match object; span=(0, 20), match='https://regexone.com'>

# %%
match.group(1)
# Out:
# 'https'

# %%
match.group(2)
# Out:
# 'regexone.com'

# %%
match.group(3)

# %%
match.group(4)

# %% [markdown]
# **문제 ?: 문자열 매칭**

# %% [markdown]
# The `re` package has a number of top level methods, and to test whether a regular expression matches a specific string in Python, you can use `re.search()`. This method either returns None if the pattern doesn't match, or a `re.MatchObject` with additional information about which part of the string the match was found.
#
# Note that this method stops after the first match, so this is best suited for testing a regular expression more than extracting data.

# %%
regex = r"([a-zA-Z]+) (\d+)"
match = re.search(regex, "June 24")

if match:
    print("Match at index %s, %s" % (match.start(), match.end()))
    
    print("Full match: %s" % (match.group(0)))
    print("Month: %s" % (match.group(1)))
    print("Day: %s" % (match.group(2)))
else:
    print("The regex pattern does not match. :(")
# Out:
# Match at index 0, 7
# Full match: June 24
# Month: June
# Day: 24

# %% [markdown]
# **문제 ?: 그룹 지정**

# %% [markdown]
# Unlike the `re.search()` method above, we can use `re.findall()` to perform a global search over the whole input string. If there are capture groups in the pattern, then it will return a list of all the captured data, but otherwise, it will just return a list of the matches themselves, or an empty list if no matches are found.
#
# If you need additional context for each match, you can use `re.finditer()` which instead returns an iterator of re.MatchObjects to walk through. Both methods take the same parameters.

# %%
regex = r"[a-zA-Z]+ \d+"
matches = re.findall(regex, "June 24, August 9, Dec 12")

for match in matches:
    print("Full match: %s" % (match))
# Out:
# Full match: June 24
# Full match: August 9
# Full match: Dec 12

# %%
matches
# Out:
# ['June 24', 'August 9', 'Dec 12']

# %%
regex = r"([a-zA-Z]+) \d+"
matches = re.findall(regex, "June 24, August 9, Dec 12")

for match in matches:
    print("Match month: %s" % (match))
# Out:
# Match month: June
# Match month: August
# Match month: Dec

# %%
matches
# Out:
# ['June', 'August', 'Dec']

# %%
regex = r"([a-zA-Z]+) \d+"
matches = re.finditer(regex, "June 24, August 9, Dec 12")

for match in matches:
    print("Match at index: %s, %s" % (match.start(), match.end()))
# Out:
# Match at index: 0, 7
# Match at index: 9, 17
# Match at index: 19, 25

# %%
matches

# %%
regex = r"([a-zA-Z]+) \d+"
matches = re.finditer(regex, "June 24, August 9, Dec 12")

for match in matches:
    print("Match at index: %s, %s" % (match.group(1), match.end()))
# Out:
# Match at index: June, 7
# Match at index: August, 17
# Match at index: Dec, 25
