# %% [markdown]
# (ch:strings-part4)=
# # 문자열 4부

# %% [markdown]
# 정규표현식<font size='2'>regular expression</font>은
# **패턴 탐색 문자열**이며 정규식 또는 레겍스(regex)라고 줄여서 불리기도 한다.
# 정규표현식은 문자열에 포함되어 있는 특정 패턴의 부분 문자열을 탐색하고 활용할 때 유용하다.

# %% [markdown]
# ## 정규표현식

# %% [markdown]
# 정규표현식은 모든 프로그래밍 언어에서 유용하게 활용된다.
# 파이썬은 `re` 모듈이 정규표현식 관련 다양한 기능을 제공하며
# 다음과 같이 불러온 후에 사용할 수 있다.

# %%
import re

# %% [markdown]
# :::{admonition} 모듈
# :class: note
#
# 파이썬 모듈은 특별한 기능을 제공하는 함수들의 모아놓은 코드 모음집 정도로 이해하면 된다.
# 앞으로 다양한 모듈 활용법을 하나씩 살펴볼 예정이다.
# :::

# %% [markdown]
# `re` 모듈은 정규표현식에 매칭되는 문자열을 찾거나 활용하는 다양한 함수들을 제공한다.
# 그중에 다음 네 개 함수가 가장 많이 사용된다.
#
# :::{list-table} 정규표현식 함수
# :widths: 10 55
# :header-rows: 1
# :name: regex-functions
#
# *   - 함수
#     - 기능
# *   - `findall()`
#     -  정규표현식에 매칭되는 모든 부분문자열로 구성된 리스트 반환
# *   - `split()`
#     -  정규표현식에 매칭되는 부분문자열을 기준으로 쪼개진 부분문자열들로 구성된 리스트 반환
# *   - `sub()`
#     -  정규표현식에 매칭되는 부분문자열이 다른 문자열로 대체된 문자열 반환
# *   - `search()`
#     -  정규표현식에 매칭되는 최초 부분문자열의 정보를 담은 `re.Match` 자료형의 값 반환.
#         못찾는 경우 `None` 반환
# :::

# %% [markdown]
# **`findall()` 함수 활용 예제**

# %% [markdown]
# 정규표현식 `'rains?'`는 `'rains'` 또는 `'rain'` 과 일치한다.
# `'s?'`는 `'s'`를 0번 또는 1번 사용하는 것을 의미한다.

# %%
text = "It rains a lot in rainy season"
re.findall('rains?', text)
# Out:
# ['rains', 'rain']

# %% [markdown]
# 정규표현식에 매칭되는 부분문자열이 없다면 비어 있는 리스트가 반환된다.

# %%
text = "It rains a lot in rainy season"
re.findall('raiins?', text)
# Out:
# []

# %% [markdown]
# **`split()` 함수 활용 예제**

# %% [markdown]
# 아래 코드는 `'rains'`와 `'rain'`을 기준으로 쪼갠 결과를 보여준다.

# %%
text = "It rains a lot in rainy season"
re.split('rains?', text)
# Out:
# ['It ', ' a lot in ', 'y season']

# %% [markdown]
# 쪼개기 횟수를 셋째 인자로 지정할 수도 있다.

# %% [markdown]
# - 한 번 쪼개기

# %%
text = "It rains a lot in rainy season"
re.split('rains?', text, 1)
# Out:
# ['It ', ' a lot in rainy season']

# %% [markdown]
# - 두 번 쪼개기

# %%
text = "It rains a lot in rainy season"
re.split('rains?', text, 2)
# Out:
# ['It ', ' a lot in ', 'y season']

# %% [markdown]
# 정규표현식에 매칭되는 부분문자열이 없다면 쪼갬이 발생하지 않는다.

# %%
text = "It rains a lot in rainy season"
re.split('raiins?', text)
# Out:
# ['It rains a lot in rainy season']

# %% [markdown]
# **`sub()` 함수 활용 예제**

# %% [markdown]
# 아래 코드는 `'rain'`을 `'snow'`로 대체한 문자열을 반환한다.

# %%
text = "It rains a lot in rainy season"
re.sub('rain', 'snow', text)
# Out:
# 'It snows a lot in snowy season'

# %% [markdown]
# 대체 횟수를 셋째 인자로 지정할 수도 있다.

# %% [markdown]
# - 한 번 대체

# %%
text = "It rains a lot in rainy season"
re.sub('rain', 'snow', text, 1)
# Out:
# 'It snows a lot in rainy season'

# %% [markdown]
# - 두 번 대체

# %%
text = "It rains a lot in rainy season"
re.sub('rain', 'snow', text, 2)
# Out:
# 'It snows a lot in snowy season'

# %% [markdown]
# 지정된 정규표현식에 매칭되는 부분문자열이 없다면 문자열 원본 그대로 반환된다.

# %%
text = "It rains a lot in rainy season"
re.sub(r'raiins?', 'snow', text)
# Out:
# 'It rains a lot in rainy season'

# %% [markdown]
# **`search()` 함수 활용 예제**

# %% [markdown]
# 아래 코드는 정규표현식 `'rains?'`와 매칭되는 `'rains'` 또는 `'rain'`을
# 주어진 문자열 왼쪽에서부터 찾으며, 가장 먼저 찾은 부분문자열의 정보를
# 담은 값이 반환된다.

# %%
text = "It rains a lot in rainy season"
match = re.search(r'rains?', text)

# %% [markdown]
# 반환된 값은 매칭된 부분문자열의 정보를 담는다.
#
# - `span`: 정규표현식에 매칭되는 부분문자열의 시작 인덱스와 끝 인덱스에 1을 더한 값으로 구성된 튜플 가리킴.
# - `match`: 정규표현식에 매칭되는 부분문자열

# %%
print(match)
# Out:
# <re.Match object; span=(3, 8), match='rains'>

# %% [markdown]
# 찾아진 값의 자료형은 `re.Match` 자료형의 값이다.

# %%
type(match)
# Out:
# re.Match

# %% [markdown]
# ## `re.Match` 객체

# %% [markdown]
# `re.Match` 객체, 즉 `re.Match` 자료형의 값은
# 정규표현식에 매칭되는 문자열에 대한 정보를 저장할 때 사용되며
# 아래 기능을 함께 제공한다.
#
# :::{list-table} `re.Match` 객체 속성과 메서드
# :widths: 10 55
# :header-rows: 1
# :name: m-object
#
# *   - 기능
#     - 설명
# *   - `string`
#     - 탐색 대상이 되는 문자열 원본을 가리키는 속성 변수
# *   - `span()`
#     - 지정된 정규표현식에 매칭되는 부분문자열의 시작 인덱스와 끝 인덱스로 구성된 튜플을 반환하는 메서드.
#         단. 끝 인덱스는 실제 끝 인덱스보다 1 큰값으로 지정됨.
# *   - `start()`
#     - 지정된 정규표현식에 매칭되는 부분문자열의 시작 인덱스를 반환하는 메서드.
# *   - `end()`
#     - 지정된 정규표현식에 매칭되는 부분문자열의 끝 인덱스를 반환하는 메서드.
#         단. 끝 인덱스는 실제 끝 인덱스보다 1 큰값으로 지정됨.
# *   - `group()`
#     - 지정된 정규표현식에 매칭되는 부분문자열을 반환하는 메서드.
# :::

# %%
match.string
# Out:
# 'It rains a lot in rainy season'

# %%
match.span()
# Out:
# (3, 8)

# %%
match.start()
# Out:
# 3

# %%
match.end()
# Out:
# 8

# %%
match.group(0)
# Out:
# 'rains'

# %% [markdown]
# 지정된 정규표현식에 매칭되는 부분문자열이 없으면 `None`이 반환된다.

# %%
text = "It rains a lot in rainy season"
match = re.search(r'raiins?', text)
print(match)
# Out:
# None

# %% [markdown]
# ## 메타 문자

# %% [markdown]
# 문자열의 백슬래시(원화 기호) `\`가 특정 문자열의 기능을 해제시키는 특별한 기능을 갖는 것처럼
# 정규표현식에서 특별한 기능을 수행하는 문자를 메타 문자라고 부른다.
# 먼저 메타 문자를 기능별로 모아서 간단한 활용 예제와 함께 소개한다.

# %% [markdown]
# **문자 선택**

# %% [markdown]
# :::{list-table} 문자 선택
# :widths: 7 10 36
# :header-rows: 1
# :name: character-selection
#
# *   - 메타 문자
#     - 활용 예제
#     - 설명
# *   - `[]`
#     - `[aeiou]`
#     - 영어 소문자 모음 알파벳 중에 하나와 매칭
# *   -
#     - `[C-Z]`
#     - 영어 대문자 알파벳 C부터 Z까지 중의 하나와 매칭
# *   -
#     - `[0-9]`
#     - 0부터 9까지의 숫자 기호 하나와 매칭
# *   -
#     - `[a-zA-Z0-9]`
#     - 영어 알파벳 또는 숫자 기호 하나와 매칭
# *   -
#     - `[abc][6-9]`
#     - `a9`, `b6`, `c8` 등과 매칭
# *   - `[^]`
#     - `[^aeiou]`
#     - 영어 소문자 모음 알파벳을 제외한 다른 하나의 문자와 매칭
# *   -
#     - `[^0-9][a-zA-Z]`
#     - 길이가 2인 문자열, 단 숫자로 시작하지 않으면서 둘째 문자는 영어 알파벳이어야 함.
# :::

# %% [markdown]
# **대표 문자**

# %% [markdown]
# :::{list-table} 대표 문자
# :widths: 7 10 36
# :header-rows: 1
# :name: representatives
#
# *   - 메타 문자
#     - 활용 예제
#     - 설명
# *   - `\`
#     - `\d`
#     - `[0-9]`와 동일
# *   -
#     - `\D`
#     - `[^0-9]`와 동일
# *   -
#     - `\s`
#     - 화이트 스페이스 하나와 매칭
# *   -
#     - `\S`
#     - 화이트 스페이스가 아닌 문자 하나와 매칭
# *   -
#     - `\w`
#     - `[a-zA-Z0-9_]`와 동일
# *   -
#     - `\W`
#     - `[^a-zA-Z0-9_]`와 동일
# *   - `.`
#     - `.`
#     - `\n`을 제외한 임의의 문자와 매칭
# *   -
#     - `..z`
#     - 영어 소문자 z로 끝나는 길이가 3인 문자열. 단, `\n`은 사용할 수 없음
# *   -
#     - `\d...\d`
#     - 숫자 기호가 양끝에 위치한 길이가 5인 문자열. 단, `\n`은 사용할 수 없음
# :::

# %% [markdown]
# **문자열 반복**

# %% [markdown]
# :::{list-table} 문자열 반복
# :widths: 7 10 36
# :header-rows: 1
# :name: string-iteration
#
# *   - 메타 문자
#     - 활용 예제
#     - 설명
# *   - `*`
#     - `be.*t`
#     - `bet`, `best`, `be3sst` 등 `be`로 시작하고 `t`로 끝나는 임의의 길이의 문자열.
#         단, `\n`은 사용 대상에서 제외.
# *   - `+`
#     - `be.+t`
#     - `be.*t`와 거의 비슷. 다만 `bet`만 제외. 즉, `be`와 `t` 최소 한 개의 문자가 와야 함.
#         단, `\n`은 사용 대상에서 제외.
# *   - `{}`
#     - `be.{2}t`
#     - `be3t`, `beast`, `besst` 등 `be`와 `t` 사이에 정확하게 2개의 문자가 사용되어야 함.
#         단, `\n`은 사용 대상에서 제외.
# *   -
#     - `be.{2,3}t`
#     - `be3t`, `be3st`, `be3sst`, `beaast` 등 `be`와 `t` 사이에 2개 또는 3개의 문자가 사용되어야 함.
#         단, `\n`은 사용 대상에서 제외.
# *   - `?`
#     - `be.?t`
#     - `be.{0,1}t`와 동일
# :::

# %% [markdown]
# **문자열 위치**

# %% [markdown]
# :::{list-table} 문자열 위치
# :widths: 7 10 36
# :header-rows: 1
# :name: string-location
#
# *   - 메타 문자
#     - 활용 예제
#     - 설명
# *   - `^`
#     - `^world`
#     - `world`로 시작하는 문자열과 매칭
# *   - `$`
#     - `world$`
#     - `world`로 끝나는 문자열과 매칭
# :::

# %% [markdown]
# :::{admonition} 캐럿<font size='2'>caret</font> `^`의 기능
# :class: note
#
# 캐럿은 두 가지 기능을 갖는다.
#
# - 첫째, `[^abc]` 처럼 대괄호로 감싸인 문자 선택 정규표현식에 사용되면 언급된 문자들을 제외시킨다.
# - 둘째, 반면에 `^abc`는 `abc`로 시작하는 문자열과 매칭된다.
# :::

# %% [markdown]
# **문자열 선택**

# %% [markdown]
# :::{list-table} 문자열 선택
# :widths: 7 10 36
# :header-rows: 1
# :name: string-selection
#
# *   - 메타 문자
#     - 활용 예제
#     - 설명
# *   - `|`
#     - `"(tom|pot)ato"`
#     - `"tomato"` 또는 `"potato"`와 매칭됨
# *   -
#     - `"^Korea|Korea$"`
#     - 문장이 `"Korea"`로 시작하거나 끝날 때 매칭됨
# *   -
#     - `"(m|j){3}bc"`
#     - `'mmmbc'`, `'iiibc'`, `'miibc'`, `'iimbc'` 등이 매칭됨.
# :::

# %% [markdown]
# **문자열 캡처**

# %% [markdown]
# :::{list-table} 문자열 캡처
# :widths: 8 10 32
# :header-rows: 1
# :name: string-capture
#
# *   - 메타 문자
#     - 활용 예제
#     - 설명
# *   - `()`
#     - `(\d+)`
#     - `2025`처럼 숫자 기호로만 구성된 부분문자열을 캡처해서 그룹으로 지정
# *   -
#     - `([a-zA-Z]+) (\d+)`
#     - `March`와 `2025`처럼 영어 알파벳으로만 구성된 부분문자열을 캡처한 그릅과 숫자 기호로만 구성된 부분문자열을 캡처한 그룹 지정
# :::

# %% [markdown]
# **캡처와 대체**

# %%
regex = r"([a-zA-Z]+) (\d+)"

print(re.sub(regex, r"\2 of \1", "June 24, August 9, Dec 12"))
# Out:
# 24 of June, 9 of August, 12 of Dec

# %%
regex = r"([a-zA-Z]+) (\d+)"

print(re.sub(regex, r"\2 of \1", "June 24, August 9, Dec 12", 1))
# Out:
# 24 of June, August 9, Dec 12

# %%
regex = r"([a-zA-Z]+) (\d+)"

print(re.sub(regex, r"\2 of \1", "June 24, August 9, Dec 12", 2))
# Out:
# 24 of June, 9 of August, Dec 12

# %% [markdown]
# ## 정규표현식 컴파일링

# %% [markdown]
# 하나의 정규표현식을 여러 번 활용하려면 먼저 컴파일을 해서 `re.RegexObject` 자료형의 값으로 만들어 두는 게 편하다.
# 예를 들어 아래 코드는 `(\w+) World`를 여러 번 사용하기 위해 먼저 컴파일시켜서 활용한다.

# %%
regex = re.compile(r"(\w+) language")

# %%
match = regex.search("Python is the easiest language.")

if match:
    print(f"시작: {match.start()}, 끝: {match.end()}")
    print(f"매칭 전체 문장: {match.group(0)}")
    print(f"매칭 문장: {match.group(1)}")
# Out:
# 시작: 14, 끝: 30
# 매칭 전체 문장: easiest language
# 매칭 문장: easiest

# %%
regex.findall("How many languages can you speak? Two languages or three?")
# Out:
# ['many', 'Two']

# %%
print("캡처된 단어: ", end='')

for word in regex.findall("How many languages can you speak? Two languages or three?"):
    print(word, end=' ')
    
print()
# Out:
# 캡처된 단어: many Two

# %%
regex.sub(r"\1 programming language", "Python is the easiest language.")
# Out:
# 'Python is the easiest programming language.'

# %% [markdown]
# ## 예제

# %% [markdown]
# **예제 1**

# %% [markdown]
# | 매칭 | 문자열 |
# | :---: | :--- |
# | 성사 | `abcdefg` |
# | 성사 | `abcde` |
# | 성사 | `abc` |

# %% [markdown]
# 답: `abc`

# %%
re.search('abc', 'abcdefg')
# Out:
# <re.Match object; span=(0, 3), match='abc'>

# %%
re.search('abc', 'abcde')
# Out:
# <re.Match object; span=(0, 3), match='abc'>

# %%
re.search('abc', 'abc')
# Out:
# <re.Match object; span=(0, 3), match='abc'>

# %% [markdown]
# **예제 2**

# %% [markdown]
# | 매칭 | 문자열 |
# | :---: | :--- |
# | 성사 | `abc123xyz` |
# | 성사 | `deine "123"` |
# | 성사 | `var g = 123;` |

# %% [markdown]
# - 숫자 활용

# %%
re.search('123', 'abc123xyz')
# Out:
# <re.Match object; span=(3, 6), match='123'>

# %%
re.search(r'\d', 'define "456789"')
# Out:
# <re.Match object; span=(8, 9), match='4'>

# %%
re.search(r'\d+', 'var g = 123;')
# Out:
# <re.Match object; span=(8, 11), match='123'>

# %% [markdown]
# - `\d` 활용

# %%
re.search(r'\d', 'abc123xyz')
# Out:
# <re.Match object; span=(3, 4), match='1'>

# %%
re.search(r'\d', 'define "123"')
# Out:
# <re.Match object; span=(8, 9), match='1'>

# %%
re.search(r'\d', 'var g = 123;')
# Out:
# <re.Match object; span=(8, 9), match='1'>

# %% [markdown]
# - `\D` 활용

# %%
re.search(r'\D*', 'abc123xyz')
# Out:
# <re.Match object; span=(0, 3), match='abc'>

# %%
re.search(r'\D', 'define "123"')
# Out:
# <re.Match object; span=(0, 1), match='d'>

# %%
re.search(r'\D', 'var g = 123;')
# Out:
# <re.Match object; span=(0, 1), match='v'>

# %% [markdown]
# **예제 2**

# %% [markdown]
# | 매칭 | 문자열 |
# | :---: | :--- |
# | 성사 | `cat.` |
# | 성사 | `896.` |
# | 성사 | `?=+.` |
# | 미성사 | `abc1` |

# %%
re.search('.', 'cat.')
# Out:
# <re.Match object; span=(0, 1), match='c'>

# %%
re.search('.', '896.')
# Out:
# <re.Match object; span=(0, 1), match='8'>

# %%
re.search('.', '?=+.')
# Out:
# <re.Match object; span=(0, 1), match='?'>

# %%
re.search(r'\.', 'abc1')

# %%
re.search(r'.{3}\.', 'cat.')
# Out:
# <re.Match object; span=(0, 4), match='cat.'>

# %%
re.search(r'.{3}\.', '896.')
# Out:
# <re.Match object; span=(0, 4), match='896.'>

# %%
re.search(r'.{3}\.', '?=+.')
# Out:
# <re.Match object; span=(0, 4), match='?=+.'>

# %%
re.search(r'.{3}\.', 'abc1')

# %% [markdown]
# **예제 2**

# %% [markdown]
# | 매칭 | 문자열 |
# | :---: | :--- |
# | 성사 | `can` |
# | 성사 | `man` |
# | 성사 | `fan` |
# | 미성사 | `dan` |
# | 미성사 | `ran` |
# | 미성사 | `pan` |

# %%
re.search('[cmf]', 'can')
# Out:
# <re.Match object; span=(0, 1), match='c'>

# %%
re.search('[cmf]', 'man')
# Out:
# <re.Match object; span=(0, 1), match='m'>

# %%
re.search('[cmf]', 'fan')
# Out:
# <re.Match object; span=(0, 1), match='f'>

# %%
re.search('[cmf]an', 'dan')

# %%
re.search('[cmf]an', 'ran')

# %%
re.search('[cmf]an', 'pan')

# %% [markdown]
# **예제 2**

# %% [markdown]
# | 매칭 | 문자열 |
# | :---: | :--- |
# | 성사 | `hog` |
# | 성사 | `dog` |
# | 미성사 | `bog` |

# %%
re.search('[^b]', 'hog')
# Out:
# <re.Match object; span=(0, 1), match='h'>

# %%
re.search('[^b]', 'dog')
# Out:
# <re.Match object; span=(0, 1), match='d'>

# %%
re.search('[^b]', 'bog')
# Out:
# <re.Match object; span=(1, 2), match='o'>

# %%
re.search('[^bo]', 'bog')
# Out:
# <re.Match object; span=(2, 3), match='g'>

# %%
re.search('[^bog]', 'bog')

# %% [markdown]
# **예제 2**

# %% [markdown]
# | 매칭 | 문자열 |
# | :---: | :--- |
# | 성사 | `Ana` |
# | 성사 | `boC` |
# | 성사 | `Cpc` |
# | 미성사 | `aax` |
# | 미성사 | `bby` |
# | 미성사 | `ccz` |

# %%
re.search('[A-C]', 'Ana')
# Out:
# <re.Match object; span=(0, 1), match='A'>

# %%
re.search('[A-C]', 'boC')
# Out:
# <re.Match object; span=(2, 3), match='C'>

# %%
re.search('[A-C]', 'Cpc')
# Out:
# <re.Match object; span=(0, 1), match='C'>

# %%
re.search('[A-C]', 'aax')

# %%
re.search('[A-C]', 'bby')

# %%
re.search('[A-C]', 'ccz')

# %%
re.search('[0-9]', '9ab')
# Out:
# <re.Match object; span=(0, 1), match='9'>

# %%
re.search('[0-9]', 'acb0')
# Out:
# <re.Match object; span=(3, 4), match='0'>

# %%
re.search(r'\w', 'acb0')
# Out:
# <re.Match object; span=(0, 1), match='a'>

# %%
re.search(r'\w', '\n')

# %%
re.search(r'\W', '\n')
# Out:
# <re.Match object; span=(0, 1), match='\n'>

# %%
re.search(r'\W', 'abc\n')
# Out:
# <re.Match object; span=(3, 4), match='\n'>

# %% [markdown]
# **예제 2**

# %% [markdown]
# | 매칭 | 문자열 |
# | :---: | :--- |
# | 성사 | `wazzzzzup` |
# | 성사 | `wazzzup` |
# | 미성사 | `wazup` |

# %%
re.search('z{3,5}', 'wazzzzzup')
# Out:
# <re.Match object; span=(2, 7), match='zzzzz'>

# %%
re.search('z{3}', 'wazzzzzup')
# Out:
# <re.Match object; span=(2, 5), match='zzz'>

# %%
re.search('zzz', 'wazzzzzup')
# Out:
# <re.Match object; span=(2, 5), match='zzz'>

# %%
re.search('z{3,5}', 'wazzzup')
# Out:
# <re.Match object; span=(2, 5), match='zzz'>

# %%
re.search('z{3,5}', 'wazzup')

# %%
re.search('z{3,5}', 'wazup')

# %% [markdown]
# **예제 2**

# %% [markdown]
# | 매칭 | 문자열 |
# | :---: | :--- |
# | 성사 | `aaaabcc` |
# | 성사 | `aabbbbc` |
# | 성사 | `aacc` |
# | 미성사 | `a` |

# %%
re.search('aa+', 'aaaabcc')
# Out:
# <re.Match object; span=(0, 4), match='aaaa'>

# %%
re.search('aa+', 'aabbbbc')
# Out:
# <re.Match object; span=(0, 2), match='aa'>

# %%
re.search('aa+', 'aacc')
# Out:
# <re.Match object; span=(0, 2), match='aa'>

# %%
re.search('aa+', 'a')

# %%
re.search('aa+', 'ab')

# %%
re.search('aa*', 'a')
# Out:
# <re.Match object; span=(0, 1), match='a'>

# %% [markdown]
# **예제 2**

# %% [markdown]
# | 매칭 | 문자열 |
# | :---: | :--- |
# | 성사 | `1 file found?` |
# | 성사 | `2 files found?` |
# | 성사 | `24 files found?` |
# | 미성사 | `No files found.` |

# %%
re.search(r'\d+.*\?', '1 file found?')
# Out:
# <re.Match object; span=(0, 13), match='1 file found?'>

# %%
re.search(r'\d+.*\?', '2 files found?')
# Out:
# <re.Match object; span=(0, 14), match='2 files found?'>

# %%
re.search(r'\d+.*\?', '24 files found?')
# Out:
# <re.Match object; span=(0, 15), match='24 files found?'>

# %%
re.search(r'\d+.*\?', 'No files found.')

# %%
re.search(r'\d\d?', '24 files found?')
# Out:
# <re.Match object; span=(0, 2), match='24'>

# %%
re.search(r'\d\d\d?', '24 files found?')
# Out:
# <re.Match object; span=(0, 2), match='24'>

# %% [markdown]
# **예제 2**

# %% [markdown]
# | 매칭 | 문자열 |
# | :---: | :--- |
# | 성사 | `1. abc` |
# | 성사 | `2.  abc` |
# | 성사 | `3.   abc` |
# | 미성사 | `4.abc` |

# %%
re.search(r'\d\.\s+abc', '1. abc')
# Out:
# <re.Match object; span=(0, 6), match='1. abc'>

# %%
re.search(r'\d\.\s+abc', '2.  abc')
# Out:
# <re.Match object; span=(0, 7), match='2.  abc'>

# %%
re.search(r'\d\.\s+abc', '3.   abc')
# Out:
# <re.Match object; span=(0, 8), match='3.   abc'>

# %%
re.search(r'\d\.\s+abc', '4.abc')

# %%
re.search(r'\d\.\S', '4.abc')
# Out:
# <re.Match object; span=(0, 3), match='4.a'>

# %% [markdown]
# **예제 2**

# %% [markdown]
# | 매칭 | 문자열 |
# | :---: | :--- |
# | 성사 | `Mission: successful` |
# | 미성사 | `Last Mission: unsuccessful` |
# | 미성사 | `Next Mission: successful upon capture of target` |

# %%
re.search('^Mission.*ful$', 'Mission: successful')
# Out:
# <re.Match object; span=(0, 19), match='Mission: successful'>

# %%
re.search('^Mission.*ful$', 'Last Mission: unsuccessful')

# %%
re.search('^Mission.*ful$', 'Next Mission: successful upon capture of target')

# %% [markdown]
# **예제 2**

# %% [markdown]
# | 그룹 지정 | 문자열 | 그룹 |
# | :---: | :--- | :--- |
# | 성사 | `file_record_transcript.pdf` | `file_record_transcript` |
# | 성사 | `file_07241999.pdf` | `file_07241999` |
# | 미성사 | `testfile_fake.pdf.tmp` | |

# %%
match = re.search(r'^file.+\.pdf$', 'file_record_trasncript.pdf')
match
# Out:
# <re.Match object; span=(0, 26), match='file_record_trasncript.pdf'>

# %%
match.group(0)
# Out:
# 'file_record_trasncript.pdf'

# %%
match.group(1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 m.group(1)
#
# IndexError: no such group

# %%
match = re.search(r'^(file.+)\.pdf$', 'file_record_trasncript.pdf')
match
# Out:
# <re.Match object; span=(0, 26), match='file_record_trasncript.pdf'>

# %%
match.group(0)
# Out:
# 'file_record_trasncript.pdf'

# %%
match.group(1)
# Out:
# 'file_record_trasncript'

# %%
match = re.search(r'^(file.+)\.(pdf)$', 'file_record_trasncript.pdf')
match
# Out:
# <re.Match object; span=(0, 26), match='file_record_trasncript.pdf'>

# %%
match.group(0)
# Out:
# 'file_record_trasncript.pdf'

# %%
match.group(1)
# Out:
# 'file_record_trasncript'

# %%
match.group(2)
# Out:
# 'pdf'

# %%
match.group(3)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 mg.group(3)
#
# IndexError: no such group

# %% [markdown]
# **예제 2**

# %% [markdown]
# | 그룹 지정 | 문자열 | 그룹 |
# | :---: | :--- | :--- |
# | 성사 | `Jan 1987` | `Jan 1987` `1987` |
# | 성사 | `May 1969` | `May 1969` `1969` |
# | 성사 | `Aug 2011` | `Aug 2011` `2011` |

# %%
match = re.search(r'(\w+ (\d+))', 'Jan 1987')

# %%
match.group(0)
# Out:
# 'Jan 1987'

# %%
match.group(1)
# Out:
# 'Jan 1987'

# %%
match.group(2)
# Out:
# '1987'

# %% [markdown]
# **예제 2**

# %% [markdown]
# | 그룹 지정 | 문자열 | 그룹 |
# | :---: | :--- | :--- |
# | 성사 | `1280x720` | `1280` `720` |
# | 성사 | `1920x1600` | `1920` `1600` |
# | 성사 | `024x768` | `1024` `768` |

# %%
match = re.search(r'(\d+)x(\d+)', '1280x720')

# %%
match.group(0)
# Out:
# '1280x720'

# %%
match.group(1)
# Out:
# '1280'

# %%
match.group(2)
# Out:
# '720'

# %%
match = re.search(r'(\d+)x(\d+)', '1920x1600')

# %%
match.group(0)
# Out:
# '1920x1600'

# %%
match.group(1)
# Out:
# '1920'

# %%
match.group(2)
# Out:
# '1600'

# %% [markdown]
# | 그룹 지정 | 문자열 | 그룹 |
# | :---: | :--- | :--- |
# | 성사 | `010-1234-5742` | `1234` `5742` |
# | 성사 | `1234-5742` | `1234` `5742` |

# %%
match = re.search(r'\d+-(\d+)-(\d+)', '010-1234-5678')
match
# Out:
# <re.Match object; span=(0, 13), match='010-1234-5678'>

# %%
match.group(0)
# Out:
# '010-1234-5678'

# %%
match.group(1)
# Out:
# '1234'

# %%
match.group(2)
# Out:
# '5678'

# %%
match = re.search(r'((\d+)-)?(\d+)-(\d+)', '1234-5678')
match
# Out:
# <re.Match object; span=(0, 9), match='1234-5678'>

# %%
match.group(0)
# Out:
# '1234-5678'

# %%
match.group(1)

# %%
match.group(2)

# %%
match.group(3)
# Out:
# '1234'

# %%
match.group(4)
# Out:
# '5678'

# %%
match = re.search(r'((\d+)-)?(\d+)-(\d+)', '010-1234-5678')
match
# Out:
# <re.Match object; span=(0, 13), match='010-1234-5678'>

# %%
match.group(0)
# Out:
# '010-1234-5678'

# %%
match.group(1)
# Out:
# '010-'

# %%
match.group(2)
# Out:
# '010'

# %%
match.group(3)
# Out:
# '1234'

# %%
match.group(4)
# Out:
# '5678'

# %% [markdown]
# **예제 2**

# %% [markdown]
# | 매칭 | 문자열 |
# | :---: | :--- |
# | 성사 | `I love cats` |
# | 성사 | `I love dogs` |
# | 미성사 | `I love logs` |
# | 미성사 | `I love cogs` |

# %%
match = re.search('I love (cats|dogs)', 'I love cats')
match
# Out:
# <re.Match object; span=(0, 11), match='I love cats'>

# %%
match.group(0)
# Out:
# 'I love cats'

# %%
match.group(1)
# Out:
# 'cats'

# %%
match.group(2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 mg.group(2)
#
# IndexError: no such group

# %%
match = re.search('I love (cats|dogs)', 'I love dogs')
match
# Out:
# <re.Match object; span=(0, 11), match='I love dogs'>

# %%
match.group(0)
# Out:
# 'I love dogs'

# %%
match.group(1)
# Out:
# 'dogs'

# %%
match.group(2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 mg.group(2)
#
# IndexError: no such group

# %%
match = re.search('I love (cats|dogs)', 'I love logs')
match

# %%
match = re.search('I love ([cb]ats*|[dh]ogs?)', 'I love hogs')
match
# Out:
# <re.Match object; span=(0, 11), match='I love hogs'>

# %%
match.group(0)
# Out:
# 'I love hogs'

# %%
match.group(1)
# Out:
# 'hogs'

# %% [markdown]
# ## 연습문제

# %% [markdown]
# 참고: [(연습) 문자열 4부](https://colab.research.google.com/github/codingalzi/42H/blob/master/practices/practice-strings_part4.ipynb)
